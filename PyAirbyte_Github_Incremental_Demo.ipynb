# %% [markdown]
# <a href="https://colab.research.google.com/github/airbytehq/quickstarts/blob/master/pyairbyte_notebooks/PyAirbyte_Github_Incremental_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this demo, we use PyAirbyte to extract data from Github, followed by a series of transformations and analyses to derive meaningful insights from this data. In particular, we demonstrate PyAirbyte capabilities for extracting data incrementally.
#
# #### Prerequisites:
#
# -   A Github personal access token. For details on configuring authetication credentials, refer to the Github source connector [documentation](https://docs.airbyte.com/integrations/sources/github).

# %%
# Add virtual environment support in Google Colab
# !apt-get install -qq python3.10-venv

# Install airbyte
# %pip install --quiet airbyte

# %% [markdown]
# ### Load source data from Github to local cache
#
# In this section, we establish a connection to Github via PyAirbyte. The source connector is configured with necessary parameters like the credentials repository we are interested in. Check the [docs](https://docs.airbyte.com/integrations/sources/github) for more details on these parameters.
#
# After configuring the source connector, we perform a `check()` to ensure that the configuration is correct and the connection to the API is successful. Then, we list the available streams for this source and select the ones we are interested in syncing.
#
# Then, we proceed to read from the source into the internal DuckDB cache.
#
# Note: The credentials are retrieved securely using the `get_secret()` method. This will automatically locate a matching Google Colab secret or environment variable, ensuring they are not hard-coded into the notebook. Make sure to add your key to the Secrets section on the left.

# %%
import airbyte as ab

# Create and configure the source:
source = ab.get_source(
    "source-github",
    install_if_missing=True,
    config={
        "repositories": ["kedro-org/kedro"],
        "credentials": {
            "personal_access_token": ab.get_secret("GITHUB_PERSONAL_ACCESS_TOKEN"),
        },
    },
)

# Verify the config and creds by running `check`:
source.check()
# Out:
# Installing 'source-github' into virtual environment
# '/Users/Nok_Lam_Chan/dev/tmp/airbyte-dataset-github-example/.venv-source-github'.
# Running 'pip install airbyte-source-github'...
# Collecting airbyte-source-github
#   Downloading airbyte_source_github-1.6.3-py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.2/247.2 kB 422.2 kB/s eta 0:00:001m398.7 kB/s eta 0:00:01
# Collecting airbyte-cdk<0.63.0,>=0.62.1
#   Downloading airbyte_cdk-0.62.2-py3-none-any.whl (695 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 695.0/695.0 kB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting sgqlc==16.3
#   Downloading sgqlc-16.3-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 2.3 MB/s eta 0:00:00
# Collecting graphql-core<4.0.0,>=3.1.7
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 2.0 MB/s eta 0:00:002.2 MB/s eta 0:00:01
# Collecting cachetools
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting isodate~=0.6.1
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.6 MB/s eta 0:00:00
# Collecting dpath~=2.0.1
#   Downloading dpath-2.0.8-py3-none-any.whl (15 kB)
# Collecting genson==1.2.2
#   Using cached genson-1.2.2-py2.py3-none-any.whl
# Collecting pydantic<2.0.0,>=1.10.8
#   Downloading pydantic-1.10.14-cp310-cp310-macosx_11_0_arm64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting requests-cache
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.3 MB/s eta 0:00:00
# Collecting Deprecated~=1.2
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting pyrate-limiter~=3.1.0
#   Downloading pyrate_limiter-3.1.1-py3-none-any.whl (23 kB)
# Collecting pendulum<3.0.0
#   Using cached pendulum-2.1.2-cp310-cp310-macosx_14_0_arm64.whl
# Collecting backoff
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting jsonschema~=3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.0 MB/s eta 0:00:00
# Collecting PyYAML>=6.0.1
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Collecting Jinja2~=3.1.2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting jsonref~=0.2
#   Downloading jsonref-0.3.0-py3-none-any.whl (8.8 kB)
# Collecting airbyte-protocol-models==0.5.1
#   Downloading airbyte_protocol_models-0.5.1-py3-none-any.whl (9.5 kB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 2.3 MB/s eta 0:00:002.6 MB/s eta 0:00:01
# Collecting wcmatch==8.4
#   Downloading wcmatch-8.4-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.6 MB/s eta 0:00:00
# Collecting bracex>=2.1.1
#   Downloading bracex-2.4-py3-none-any.whl (11 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_universal2.whl (18 kB)
# Requirement already satisfied: setuptools in ./.venv-source-github/lib/python3.10/site-packages (from jsonschema~=3.2.0->airbyte-cdk<0.63.0,>=0.62.1->airbyte-source-github) (65.5.0)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.20.0-cp310-cp310-macosx_10_9_universal2.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 5.9 MB/s eta 0:00:00
# Collecting attrs>=17.4.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting cattrs>=22.2
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.7 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting exceptiongroup>=1.1.1
#   Using cached exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: genson, wrapt, urllib3, typing-extensions, six, PyYAML, pytzdata, pyrsistent, pyrate-limiter, platformdirs, MarkupSafe, jsonref, idna, graphql-core, exceptiongroup, dpath, charset-normalizer, certifi, cachetools, bracex, backoff, attrs, wcmatch, url-normalize, sgqlc, requests, python-dateutil, pydantic, jsonschema, Jinja2, isodate, Deprecated, cattrs, requests-cache, pendulum, airbyte-protocol-models, airbyte-cdk, airbyte-source-github
# Successfully installed Deprecated-1.2.14 Jinja2-3.1.3 MarkupSafe-2.1.5 PyYAML-6.0.1 airbyte-cdk-0.62.2 airbyte-protocol-models-0.5.1 airbyte-source-github-1.6.3 attrs-23.2.0 backoff-2.2.1 bracex-2.4 cachetools-5.3.3 cattrs-23.2.3 certifi-2024.2.2 charset-normalizer-3.3.2 dpath-2.0.8 exceptiongroup-1.2.0 genson-1.2.2 graphql-core-3.2.3 idna-3.6 isodate-0.6.1 jsonref-0.3.0 jsonschema-3.2.0 pendulum-2.1.2 platformdirs-4.2.0 pydantic-1.10.14 pyrate-limiter-3.1.1 pyrsistent-0.20.0 python-dateutil-2.9.0.post0 pytzdata-2020.1 requests-2.31.0 requests-cache-1.2.0 sgqlc-16.3 six-1.16.0 typing-extensions-4.10.0 url-normalize-1.4.3 urllib3-2.2.1 wcmatch-8.4 wrapt-1.16.0
# Connector 'source-github' installed successfully!
# For more information, see the source-github documentation:
# https://docs.airbyte.com/integrations/sources/github#reference
# Connection check succeeded for `source-github`.

# %%
# List the available streams available for the Github source
source.get_available_streams()
# Out:
# ['issue_timeline_events',
#  'assignees',
#  'branches',
#  'collaborators',
#  'comments',
#  'commit_comment_reactions',
#  'commit_comments',
#  'commits',
#  'contributor_activity',
#  'deployments',
#  'events',
#  'issue_comment_reactions',
#  'issue_events',
#  'issue_labels',
#  'issue_milestones',
#  'issue_reactions',
#  'issues',
#  'organizations',
#  'project_cards',
#  'project_columns',
#  'projects',
#  'pull_request_comment_reactions',
#  'pull_request_commits',
#  'pull_request_stats',
#  'projects_v2',
#  'pull_requests',
#  'releases',
#  'repositories',
#  'review_comments',
#  'reviews',
#  'stargazers',
#  'tags',
#  'teams',
#  'team_members',
#  'users',
#  'workflows',
#  'workflow_runs',
#  'workflow_jobs',
#  'team_memberships']

# %%
# Select the streams we are interested in loading to cache
source.set_streams(["pull_requests", "issues", "reviews", "stargazers"])

# Read into DuckDB local default cache
cache = ab.get_default_cache()
result = source.read(cache=cache)
# Out:
# ## Read Progress
#
# Started reading at 23:44:40.
#
# Read **22,168** records over **7min 57s** (46.5 records / second).
#
# Wrote **22,168** records over 4 batches.
#
# Finished reading at 23:52:38.
#
# Started finalizing streams at 23:52:38.
#
# Finalized **4** batches over 1 seconds.
#
# Completed 4 out of 4 streams:
#
#   - pull_requests
#   - reviews
#   - issues
#   - stargazers
#
#
# Completed writing at 23:52:40. Total time elapsed: 7min 59s
#
#
# ------------------------------------------------
# Completed `source-github` read operation at 23:52:40.

# %% [markdown]
# ### Read again to sync changes
#
# The PyAirbyte Github source connector has the ability to read data incrementally by default, meaning that after the first successful data sync, only updates and new records will be synced in subsequent reads.
#
# For more information on sync modes for this source, you can refer to the [docs](https://docs.airbyte.com/integrations/sources/github).
#
# Let's read again, and see how no records will be loaded to cache.

# %%
result = source.read(cache=cache)
# Out:
# ## Read Progress
#
# Started reading at 23:53:11.
#
# Read **0** records over **1min 1s** (0.0 records / second).
#
#
#
#
# ------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = source.read(cache=cache)
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/source.py:631, in Source.read(self, cache, streams, write_strategy, force_full_refresh)
#     629 self._log_sync_start(cache=cache)
#     630 try:
# --> 631     cache.processor.process_airbyte_messages(
#     632         self._read_with_catalog(
#     633             catalog=self.configured_catalog,
#     634             state=state,
#     635         ),
#     636         write_strategy=write_strategy,
#     637     )
#     638 except Exception as ex:
#     639     self._log_sync_failure(cache=cache, exception=ex)
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/_processors/base.py:179, in RecordProcessor.process_airbyte_messages(self, messages, write_strategy, max_batch_size)
#     177 stream_batches: dict[str, list[dict]] = defaultdict(list, {})
#     178 # Process messages, writing to batches as we go
# --> 179 for message in messages:
#     180     if message.type is Type.RECORD:
#     181         record_msg = cast(AirbyteRecordMessage, message.record)
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/source.py:455, in Source._read_with_catalog(self, catalog, state)
#     443 self._processed_records = 0  # Reset the counter before we start
#     444 with as_temp_files(
#     445     [
#     446         self._config,
#    (...)
#     453     state_file,
#     454 ]:
# --> 455     yield from self._tally_records(
#     456         self._execute(
#     457             [
#     458                 "read",
#     459                 "--config",
#     460                 config_file,
#     461                 "--catalog",
#     462                 catalog_file,
#     463                 "--state",
#     464                 state_file,
#     465             ],
#     466         )
#     467     )
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/source.py:512, in Source._tally_records(self, messages)
#     509 self._processed_records = 0  # Reset the counter before we start
#     510 progress.reset(len(self._selected_stream_names or []))
# --> 512 for message in messages:
#     513     yield message
#     514     progress.log_records_read(self._processed_records)
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/source.py:487, in Source._execute(self, args)
#     485 try:
#     486     self._last_log_messages = []
# --> 487     for line in self.executor.execute(args):
#     488         try:
#     489             message = AirbyteMessage.parse_raw(line)
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/_executor.py:384, in VenvExecutor.execute(self, args)
#     381 connector_path = self._get_connector_path()
#     383 with _stream_from_subprocess([str(connector_path), *args]) as stream:
# --> 384     yield from stream
#
# File ~/miniconda3/envs/kedro/lib/python3.10/site-packages/airbyte/_executor.py:82, in _stream_from_subprocess.<locals>._stream_from_file(file)
#      80 def _stream_from_file(file: IO[str]) -> Generator[str, Any, None]:
#      81     while True:
# ---> 82         line = file.readline()
#      83         if not line:
#      84             break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Read data from the cache
#
# Read from the already-written DuckDB cache into a pandas Dataframe. After the data is in the cache, you can read it without re-configuring or re-creating the source object. You can also select a specific stream to read from.

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
type(cache)
# Out:
# airbyte.caches.duckdb.DuckDBCache

# %%
# Read from the cache into a pandas Dataframe:
reviews = cache["reviews"].to_pandas()
stargazers = cache["stargazers"].to_pandas()
pull_requests = cache["pull_requests"].to_pandas()
issues = cache["issues"].to_pandas()

# %% [markdown]
# ### Transform and analyze the data
#
# Let's take our Github data and run some analysis with `pandas` and `matplotlib`.

# %%
reviews.head(3)
# Out:
#         repository         id                                   node_id  \
# 0  kedro-org/kedro  246057197  MDE3OlB1bGxSZXF1ZXN0UmV2aWV3MjQ2MDU3MTk3
# 1  kedro-org/kedro  246417296  MDE3OlB1bGxSZXF1ZXN0UmV2aWV3MjQ2NDE3Mjk2
# 2  kedro-org/kedro  246980975  MDE3OlB1bGxSZXF1ZXN0UmV2aWV3MjQ2OTgwOTc1
#
#                                                 user  \
# 0  {"avatar_url":"https://avatars.githubuserconte...
# 1  {"avatar_url":"https://avatars.githubuserconte...
# 2  {"avatar_url":"https://avatars.githubuserconte...
#
#                            body     state  \
# 0  LGTM! Thank you for the fix!  APPROVED
# 1                                APPROVED
# 2                                APPROVED
#
#                                             html_url  \
# 0  https://github.com/kedro-org/kedro/pull/10#pul...
# 1  https://github.com/kedro-org/kedro/pull/10#pul...
# 2  https://github.com/kedro-org/kedro/pull/10#pul...
#
#                              pull_request_url  \
# 0  https://github.com/kedro-org/kedro/pull/10
# 1  https://github.com/kedro-org/kedro/pull/10
# 2  https://github.com/kedro-org/kedro/pull/10
#
#                                               _links        submitted_at  \
# 0  {"html":{"href":"https://github.com/kedro-org/... 2019-06-05 14:46:50
# 1  {"html":{"href":"https://github.com/kedro-org/... 2019-06-06 08:08:50
# 2  {"html":{"href":"https://github.com/kedro-org/... 2019-06-07 08:51:54
#
#            created_at          updated_at  \
# 0 2019-06-05 14:46:50 2019-06-05 14:46:50
# 1 2019-06-06 08:08:50 2019-06-06 08:08:50
# 2 2019-06-07 08:51:54 2019-06-07 08:51:54
#
#                                   commit_id author_association
# 0  781dd7c0ad381a4ffedc360a6e3a7778c5b05c2c        CONTRIBUTOR
# 1  7b8f6de4b1285f2e06c6749f170c40a4aabcfa59        CONTRIBUTOR
# 2  7b8f6de4b1285f2e06c6749f170c40a4aabcfa59             MEMBER

# %%
stargazers.head(3)
# Out:
#         repository   user_id          starred_at  \
# 0  kedro-org/kedro  44967953 2019-05-01 10:01:52
# 1  kedro-org/kedro  20123973 2019-05-02 04:43:19
# 2  kedro-org/kedro  50255759 2019-05-13 17:12:47
#
#                                                 user
# 0  {"avatar_url":"https://avatars.githubuserconte...
# 1  {"avatar_url":"https://avatars.githubuserconte...
# 2  {"avatar_url":"https://avatars.githubuserconte...

# %%
pull_requests.head(3)
# Out:
#         repository                                                url  \
# 0  kedro-org/kedro  https://api.github.com/repos/kedro-org/kedro/p...
# 1  kedro-org/kedro  https://api.github.com/repos/kedro-org/kedro/p...
# 2  kedro-org/kedro  https://api.github.com/repos/kedro-org/kedro/p...
#
#           id                           node_id  \
# 0  273543444  MDExOlB1bGxSZXF1ZXN0MjczNTQzNDQ0
# 1  285393014  MDExOlB1bGxSZXF1ZXN0Mjg1MzkzMDE0
# 2  286510945  MDExOlB1bGxSZXF1ZXN0Mjg2NTEwOTQ1
#
#                                      html_url  \
# 0   https://github.com/kedro-org/kedro/pull/1
# 1  https://github.com/kedro-org/kedro/pull/10
# 2  https://github.com/kedro-org/kedro/pull/16
#
#                                           diff_url  \
# 0   https://github.com/kedro-org/kedro/pull/1.diff
# 1  https://github.com/kedro-org/kedro/pull/10.diff
# 2  https://github.com/kedro-org/kedro/pull/16.diff
#
#                                           patch_url  \
# 0   https://github.com/kedro-org/kedro/pull/1.patch
# 1  https://github.com/kedro-org/kedro/pull/10.patch
# 2  https://github.com/kedro-org/kedro/pull/16.patch
#
#                                            issue_url  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...
# 1  https://api.github.com/repos/kedro-org/kedro/i...
# 2  https://api.github.com/repos/kedro-org/kedro/i...
#
#                                          commits_url  \
# 0  https://api.github.com/repos/kedro-org/kedro/p...
# 1  https://api.github.com/repos/kedro-org/kedro/p...
# 2  https://api.github.com/repos/kedro-org/kedro/p...
#
#                                  review_comments_url  ...  \
# 0  https://api.github.com/repos/kedro-org/kedro/p...  ...
# 1  https://api.github.com/repos/kedro-org/kedro/p...  ...
# 2  https://api.github.com/repos/kedro-org/kedro/p...  ...
#
#                                             assignee  \
# 0                                               None
# 1  {"avatar_url":"https://avatars.githubuserconte...
# 2                                               None
#
#                                            assignees  \
# 0                                                 []
# 1  [{"avatar_url":"https://avatars.githubusercont...
# 2                                                 []
#
#                                  requested_reviewers  requested_teams  \
# 0                                                 []               []
# 1  [{"avatar_url":"https://avatars.githubusercont...               []
# 2  [{"avatar_url":"https://avatars.githubusercont...               []
#
#                                                 head  \
# 0  {"label":"kedro-org:develop","ref":"develop","...
# 1  {"label":"dazzag24:patch-1","ref":"patch-1","r...
# 2  {"label":"mzjp2:dev-doc/cli","ref":"dev-doc/cl...
#
#                                                 base  \
# 0  {"label":"kedro-org:master","ref":"master","re...
# 1  {"label":"kedro-org:develop","ref":"develop","...
# 2  {"label":"kedro-org:develop","ref":"develop","...
#
#                                               _links author_association  \
# 0  {"comments":{"href":"https://api.github.com/re...               NONE
# 1  {"comments":{"href":"https://api.github.com/re...        CONTRIBUTOR
# 2  {"comments":{"href":"https://api.github.com/re...        CONTRIBUTOR
#
#   auto_merge  draft
# 0       None  False
# 1       None  False
# 2       None  False
#
# [3 rows x 37 columns]

# %%
issues.head(3)
# Out:
#         repository         id                           node_id  \
# 0  kedro-org/kedro  437222337  MDExOlB1bGxSZXF1ZXN0MjczNTQzNDQ0
# 1  kedro-org/kedro  446218522          MDU6SXNzdWU0NDYyMTg1MjI=
# 2  kedro-org/kedro  452459807          MDU6SXNzdWU0NTI0NTk4MDc=
#
#                                                  url  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...
# 1  https://api.github.com/repos/kedro-org/kedro/i...
# 2  https://api.github.com/repos/kedro-org/kedro/i...
#
#                                  repository_url  \
# 0  https://api.github.com/repos/kedro-org/kedro
# 1  https://api.github.com/repos/kedro-org/kedro
# 2  https://api.github.com/repos/kedro-org/kedro
#
#                                           labels_url  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...
# 1  https://api.github.com/repos/kedro-org/kedro/i...
# 2  https://api.github.com/repos/kedro-org/kedro/i...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...
# 1  https://api.github.com/repos/kedro-org/kedro/i...
# 2  https://api.github.com/repos/kedro-org/kedro/i...
#
#                                           events_url  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...
# 1  https://api.github.com/repos/kedro-org/kedro/i...
# 2  https://api.github.com/repos/kedro-org/kedro/i...
#
#                                       html_url  number  ...  \
# 0    https://github.com/kedro-org/kedro/pull/1       1  ...
# 1  https://github.com/kedro-org/kedro/issues/2       2  ...
# 2  https://github.com/kedro-org/kedro/issues/9       9  ...
#
#                                         pull_request           closed_at  \
# 0  {"diff_url":"https://github.com/kedro-org/kedr... 2019-04-25 14:13:13
# 1                                               None 2019-05-26 12:31:10
# 2                                               None 2019-06-05 13:24:57
#
#            created_at          updated_at author_association  draft  \
# 0 2019-04-25 14:12:24 2019-04-25 14:13:13               NONE  False
# 1 2019-05-20 16:58:10 2019-05-26 12:31:10        CONTRIBUTOR   None
# 2 2019-06-05 11:53:27 2019-06-05 13:24:58        CONTRIBUTOR   None
#
#                                            reactions  \
# 0  {"+1":0,"-1":0,"confused":0,"eyes":0,"heart":0...
# 1  {"+1":0,"-1":0,"confused":0,"eyes":0,"heart":0...
# 2  {"+1":0,"-1":0,"confused":0,"eyes":0,"heart":0...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/kedro-org/kedro/i...                     None
# 1  https://api.github.com/repos/kedro-org/kedro/i...                     None
# 2  https://api.github.com/repos/kedro-org/kedro/i...                     None
#
#    state_reason
# 0          None
# 1     completed
# 2     completed
#
# [3 rows x 32 columns]

# %% [markdown]
# #### Pull Requests Trend Over Time
#
# This will visualize the number of pull requests created over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'pull_requests' dataframe is available and has a 'created_at' column in datetime format
pull_requests["created_at"] = pd.to_datetime(pull_requests["created_at"])
pr_trend = pull_requests.resample("M", on="created_at").size()

plt.figure(figsize=(12, 6))
pr_trend.plot(kind="line", color="blue", marker="o")
plt.title("Monthly Pull Requests Trend")
plt.xlabel("Month")
plt.ylabel("Number of Pull Requests")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Open vs Closed Issues
#
# Compare the number of open versus closed issues.

# %%
# Assuming 'issues' dataframe has a 'state' column
issue_status_count = issues["state"].value_counts()

plt.figure(figsize=(8, 6))
issue_status_count.plot(kind="bar", color=["blue", "green"])
plt.title("Open vs Closed Issues")
plt.xlabel("State")
plt.ylabel("Number of Issues")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Star Growth Over Time
#
# Plot the cumulative count of stars over time.

# %%
# Assuming 'stargazers' dataframe has a 'starred_at' column in datetime format
stargazers["starred_at"] = pd.to_datetime(stargazers["starred_at"])
star_growth = stargazers.resample("M", on="starred_at").size().cumsum()

plt.figure(figsize=(12, 6))
star_growth.plot(kind="line", color="gold", marker="*")
plt.title("Cumulative Star Growth Over Time")
plt.xlabel("Month")
plt.ylabel("Cumulative Stars")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Issue Resolution Followed by Pull Requests
#
# This analysis checks if there's a trend in issue resolutions followed by pull requests, which might indicate active development in response to issues.

# %%
# Convert created_at and closet_at to datetime
pull_requests["created_at"] = pd.to_datetime(pull_requests["created_at"])
issues["closed_at"] = issues["closed_at"].dt.tz_localize(None)

# Resample both dataframes to get monthly counts
monthly_closed_issues = issues.resample("M", on="closed_at").size()
monthly_created_prs = pull_requests.resample("M", on="created_at").size()

# Combine into a single dataframe
combined_issues_prs_df = pd.concat([monthly_closed_issues, monthly_created_prs], axis=1)
combined_issues_prs_df.columns = ["Monthly Closed Issues", "Monthly Created PRs"]

# %%
combined_issues_prs_df.plot(kind="line", figsize=(12, 6))
plt.title("Monthly Closed Issues vs Monthly Created Pull Requests")
plt.xlabel("Month")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %% [markdown]
# # Reproduce example with a Kedro Dataset

# %%
from typing import Any, Dict
import numpy as np
from kedro.io import AbstractDataset
import airbyte as ab

class AirbyteDataset(AbstractDataset):
    def __init__(self, repositories: list[str], streams: list[str],install_if_missing=True, ):
        # self._filepath = filepath
        repositories = ["kedro-org/kedro"] # TODO: generic
        streams = ["pull_requests", "issues", "reviews", "stargazers"] #TODO : generic
        
        self.repositories = repositories
        self.streams = streams
        
        token = ab.get_secret("GITHUB_PERSONAL_ACCESS_TOKEN")
        self.source = ab.get_source(
            "source-github",
            install_if_missing=install_if_missing,
            config={
                "repositories": repositories ,
                "credentials": {
                    "personal_access_token": token,
                },
            },
        )
        # Select the streams we are interested in loading to cache
        self.source.set_streams(streams)


    def _load(self) -> np.ndarray:
        # Read into DuckDB local default cache
        self.cache = ab.get_default_cache()
        result = self.source.read(cache=self.cache)
        return result

    def _save(self, data: np.ndarray) -> None:
        ...

    def _describe(self) -> Dict[str, Any]:
        ...

# %% [markdown]
# #### Star Growth Over Time
#
# Plot the cumulative count of stars over time.

# %%
airbyte_dataset = AirbyteDataset(repositories=["kedro-org/kedro"],streams = ["stargazers"])
# Out:
# /var/folders/qq/wpp9vnws3sqcv6v3td68qcpm0000gp/T/ipykernel_74515/318769736.py:27: DeprecationWarning: The 'set_streams' method is deprecated and will be removed in a future version. Please use the 'select_streams' method instead.
#   self.source.set_streams(streams)

# %%
result = airbyte_dataset.load()
# Out:
# ## Read Progress
#
# Started reading at 00:02:40.
#
# Read **0** records over **2min 0s** (0.0 records / second).
#
# Finished reading at 00:04:40.
#
# Started finalizing streams at 00:04:40.
#
# Finalized **0** batches over 0 seconds.
#
# Completed 4 out of 4 streams:
#
#   - pull_requests
#   - issues
#   - reviews
#   - stargazers
#
#
# Completed writing at 00:04:40. Total time elapsed: 2min 0s
#
#
# ------------------------------------------------
# Completed `source-github` read operation at 00:04:40.

# %%
stargazers = cache["stargazers"].to_pandas()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Assuming 'stargazers' dataframe has a 'starred_at' column in datetime format
stargazers["starred_at"] = pd.to_datetime(stargazers["starred_at"])
star_growth = stargazers.resample("M", on="starred_at").size().cumsum()

plt.figure(figsize=(12, 6))
star_growth.plot(kind="line", color="gold", marker="*")
plt.title("Cumulative Star Growth Over Time")
plt.xlabel("Month")
plt.ylabel("Cumulative Stars")
plt.grid(True)
plt.show()

# %% [markdown]
# # Summary
# - Airbytes has its own caching mechanism, it has incremental changes so I used `AbstractDataset` instead of `AbstractVersionedDataset`
# - Is it's better to separate to two steps, the first steps use the connector to extract data as a duckdb cache, and second step to load the duckdb cache?
